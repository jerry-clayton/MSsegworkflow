# %% [markdown]
# # Mean Shift Segmentation Batch Runner
#
# Author: [Jerry Clayton](https://github.com/jerry-clayton)
#
# For: [Ni-Meister Lab](http://www.geography.hunter.cuny.edu/~wenge/)
#
# Adapted from [Ian Grant's Script](https://github.com/i-c-grant/ni-meister-gedi-biomass/blob/main/run_on_maap.py)
#
# #### This Jupyter notebook handles the batch processing of the modified Mean Shift tree segmentation workflow developed by the author and Dr. Ni-Meister on the NASA MAAP platform.
#
# #### The [AMS3D](https://www.sciencedirect.com/science/article/abs/pii/S0034425716302292) was first proposed by Ferraz et. al, and this implementation depends on Dr. Nikolai Knapp's [MeanShiftR](https://github.com/niknap/MeanShiftR/tree/master/R) package
#
# #### This workflow is executed in four parts: Split, Segment, Reconcile, and Merge

# %%
import datetime
import logging
import os
import shutil
import time
import glob
import tarfile
import pickle

import warnings
from pathlib import Path
from typing import Dict, List

import click
import geopandas as gpd
import pandas as pd
from tqdm import tqdm
from geopandas import GeoDataFrame
from maap.maap import MAAP
from maap.Result import Granule

maap = MAAP(maap_host='api.maap-project.org')

# %%
def build_file_url(filename):
    url_first_part = "s3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/" 
    url = f'{url_first_part}{filename}'
    return url

def build_test_file_url(filename):
    url_first_part = "s3://maap-ops-workspace/jclayton0/test-input-sm-tiles/" 
    url = f'{url_first_part}{filename}'
    return url

def get_split_kwargs(fileurl):
     job_kwargs = {
            "identifier": "Mean Shift Split LAS",
            "algo_id": "MS-Step-1-Split",
            "version": "main",
            "username": "jclayton0",
            "queue": "maap-dps-worker-64gb",
            "LAS": fileurl,
            "Subplot_width": 25,
            "Buffer_width": 10
    }
    
     return job_kwargs

def get_segment_kwargs(fileurl):
    job_kwargs = {
            "identifier": "Mean Shift Segment LAS",
            "algo_id": "MS-Step-2-Segment-v2",
            "version": "main",
            "username": "jclayton0",
            "queue": "maap-dps-cuny-worker-64gb",
            "Point Cloud RDS": fileurl,
            "Subplot_widthFrac_cores": 0.9
    }
    
    return job_kwargs

def get_reconcile_kwargs(tarball_url, las_url):
    job_kwargs = {
            "identifier": "Mean Shift Reconcile LAS",
            "algo_id": "MS-Step-3-Reconcile-v3",
            "version": "main",
            "username": "jclayton0",
            "queue": "maap-dps-worker-64gb",
            "tarball": tarball_url,
            "original_las": las_url
    }
    
    return job_kwargs

def get_merge_kwargs(fileurl):
    job_kwargs = {
            "identifier": "Mean Shift Merge Trees",
            "algo_id": "MS-Step-4-Merge",
            "version": "main",
            "username": "jclayton0",
            "queue": "maap-dps-worker-64gb",
            "segmented_las": fileurl
    }
    
    return job_kwargs

# %%
def local_url_to_s3(url):
    second = str.split(url,"my-private-bucket")[1]
    full = f"s3://maap-ops-workspace/jclayton0{second}"
    return full

def get_old_jobs_list(old_jobs_path):
    
    with open(old_jobs_path, 'r') as file:
        old_jobs = file.readlines()
    
    old_jobs = [line.strip() for line in old_jobs]
    return old_jobs

def get_succeeded_jobs_in_list(job_ids):
    
    succeeded_job_ids = [job_id for job_id in job_ids
                         if job_status_for(job_id) == "Succeeded"]
    return succeeded_job_ids

def get_failed_jobs_in_list(job_ids):
    
    failed_job_ids = [job_id for job_id in job_ids
                      if job_status_for(job_id) == "Failed"]
    return failed_job_ids

def get_other_status_jobs_in_list(job_ids):

    other_job_ids = [job_id for job_id in job_ids
                     if job_status_for(job_id)
                     not in ["Succeeded", "Failed"]]
    return other_job_ids

def get_unsuccessful_jobs_in_list(job_ids):
    
    unsuccessful_job_ids = [job_id for job_id in job_ids
        if job_status_for(job_id) != "Succeeded"]
    
    return unsuccessful_job_ids

import json
def get_failed_job_input_LAS(failed_json_path):

    with open(failed_json_path,'r') as file:
        data = json.load(file)
        
    return data.get('params').get('job_specification').get('params')[0].get('value')

# %%
def job_status_for(job_id: str) -> str:
    return maap.getJobStatus(job_id)

def job_result_for(job_id: str) -> str:
    return maap.getJobResult(job_id)[0]

def to_job_output_dir(job_result_url: str, username: str) -> str:
    return (f"/projects/my-private-bucket/"
            f"{job_result_url.split(f'/{username}/')[1]}")

def to_failed_job_params(job_result_url: str) -> str:
    return (f"../triaged-jobs/"
            f"{job_result_url.split(f'/triaged_job/')[1]}/_job.json")


def log_and_print(message: str):
    logging.info(message)
    click.echo(message)

def update_job_states(job_states: Dict[str, str],
                      final_states: List[str],
                      batch_size: int,
                      delay: int) -> Dict[str, str]:
    """Update the job states dictionary in place.

    Updating occurs in batches, with a delay in seconds between batches.

    Return the number of jobs updated to final states.
    """
    batch_count = 0
    n_updated_to_final = 0
    for job_id, state in job_states.items():
        if state not in final_states:
            new_state: str = job_status_for(job_id)
            job_states[job_id] = new_state
            if new_state in final_states:
                n_updated_to_final += 1
            batch_count += 1
        # Sleep after each batch to avoid overwhelming the API
        if batch_count == batch_size:
            time.sleep(delay)
            batch_count = 0

    return n_updated_to_final

# %%
maap.getQueues().json()
# Out:
# {'code': 200,
#  'message': 'success',
#  'queues': ['maap-dps-sandbox',
#   'maap-dps-cuny-worker-64gb',
#   'maap-dps-worker-64gb',
#   'maap-dps-cuny-worker-512gb',
#   'maap-dps-worker-32vcpu-64gb',
#   'maap-dps-worker-32gb',
#   'maap-dps-worker-8gb',
#   'maap-dps-worker-16gb']}

# %%
old_jobs_path = "../my-private-bucket/run_output_20241115_131005/job_ids.txt"
old_output_dir = "../my-private-bucket/run_output_20241115_131005/"
old_jobs = get_old_jobs_list(old_jobs_path)
old_jobs
# Out:
# ['b2f2322d-4cf9-4b8b-8825-6027004910a0',
#  '59446f2e-42fd-4666-a43f-d4a343df4824',
#  'd80f1710-9bc0-42c8-a57d-dc9556bb9368',
#  'c4c20041-a659-497b-90ac-c1e9f6f0037d',
#  '01f47c4c-7e86-456c-b76b-690a3e3a5a2b',
#  'c14fc301-3497-4d5d-9794-526ec1d12d67',
#  '1d420f6a-2c33-4952-9496-0724e28caa21',
#  '62315dc4-6f4d-400d-9369-a5e4ae42e91a',
#  'f68564cf-0f7d-4a66-9dff-424da5274366',
#  '868e2dab-0118-4999-b6a2-ff860e0877da',
#  'ae6a8cea-e1d2-4d4c-8145-d9e3c86ef651',
#  '9ab1f156-940b-4e85-afaf-1ea4df03ad12',
#  '7ce55e8c-b983-4350-8bfa-0a25961d605e',
#  'ea7a32fc-c046-4ce8-9db4-1a32741ac34f',
#  '6064599c-7eaf-421d-ae07-5c8e5bc81d59',
#  '434b63a7-7d05-4209-b5a6-c02f640e6be4',
#  'd6392c13-0fa8-4c48-a823-767fecec6600',
#  '4dec228e-d76f-4b61-bfe7-6067949eb44b',
#  '6c131c5b-f4b1-4587-b413-eeae1349f8ad',
#  '00a36ef2-edaf-4bc9-9236-daee2c2347b4',
#  'ca54f470-f35d-4312-b230-7346b71c7744',
#  'c48609ba-9427-4cf0-b65e-43463d719211',
#  'ff2f2e29-18e3-4ea4-83d1-4cbc4b3c7930',
#  '40c94625-038f-4531-aa05-553f3ba9eb8f',
#  '837f77d7-aabd-4247-ac96-56d87a694125',
#  '4a946bba-13b6-485b-a628-25283bc38fe0',
#  '12735858-be83-42b4-8351-cc4f7efaab53',
#  '57ded4fc-1f94-4330-b043-931b237b8c1d',
#  '45c5c5ed-bb45-4e4e-98ad-38a0d8fb1a3d',
#  'de79b89f-1bde-4487-a5f0-218bcd6bd801',
#  '08c126f1-2d03-4f7b-a903-83a15a0b10f3',
#  'aa4d5585-79c0-460c-bbae-9e9b791df963',
#  'd450017d-79d6-45b3-8497-32a53695ea3f',
#  '2e0fe019-1edd-41ab-938b-77edb8481062',
#  'a1f87758-d8f9-4472-ab9e-b3a4a5c4c569',
#  '6af9d62d-f05a-4a76-b453-3649aa8eebb5',
#  '2be30bf8-3dee-4f9b-ac93-c943e1170905',
#  '30a21c62-606a-40af-a66f-28514d1be6a3',
#  'bcb1051c-4200-4f10-98cb-bbf5431345f3',
#  '220752b3-4c42-4af2-8ff7-ba402378a570',
#  '2f3d665f-e10a-47b9-aadd-0f47bb39a4b1',
#  'f6aea96b-9352-4207-9c3a-b8b4de2200b9',
#  'a6bfc28c-c0ae-4e8c-91e0-7467a648471b',
#  '445cf644-d954-4fd9-98d8-e74b1541d3dd',
#  '91a31159-aeb0-4827-a615-58b2319e5046',
#  'd7d89c5b-1d12-49f6-83ee-cd8d100780da',
#  '255cd4d0-db33-48b1-a06a-83f339523512',
#  'b622b6ed-0f94-48d7-b415-f4e02b92094c',
#  'b0a370b5-fe50-4fe9-b6bc-4ceeccf66420',
#  'e10a6173-b63a-4857-9ac9-0e44ed795246',
#  '168cc00c-2026-42bb-9cfc-77d4bceea26a',
#  'ef1798e6-bc3e-44a0-a781-71a751a4a084',
#  '5439400b-e08d-4791-ac6f-d15a32830460',
#  'a01bde25-7088-4194-b277-511cd27eafe6',
#  'c9e42b11-c79d-4046-bac9-84cc8d590b49',
#  '42bb3b70-9616-4ea0-be60-5e2489373376',
#  '59f245c7-08a3-4667-83fe-eb3267c6e984',
#  '3680faf5-f46b-4ea4-9392-fed9db0cf80f',
#  '2619a508-3ad6-4583-9243-4b0a2040c703',
#  'e48d3581-c715-48c3-8185-b2156ea9b965',
#  '44ba4c2d-5cb8-467e-97db-63d4727e93ba',
#  '4261a674-a331-49c1-89b1-4971ff1efd5f',
#  'e0f94a1e-3b6b-4b90-89fd-180e95a0612b',
#  'a067415b-0701-43f4-9d3b-82b7f66a81be',
#  'afdc3bb6-d458-4a9f-b167-7206adc1d5b1',
#  'dd8547b4-cf83-4355-9376-6350dd764ba5',
#  'c659e94e-2656-44eb-8f03-862d36938544',
#  'e07d339f-fcd0-4b83-ba3c-dbeabc50f2a3',
#  'a1c0f4d1-32ce-4a00-b46c-da8f64fbbbba',
#  'f1d46eea-278c-4e12-bcdd-3bca90dbd1ad',
#  '4cbc9145-fcfc-4e6f-bb8d-cec22f60b300',
#  '2cfb6288-75d4-4226-9fdf-73ec037513e9',
#  '471d213c-bf46-4f1a-83b8-1cffd652289e',
#  '2e4146ff-1973-4b1d-a627-63fbb13a7845',
#  'c5901ee8-4d46-405e-8b41-c542bcdd7c2c',
#  'cc12286a-7891-4890-9950-15a3e5b93f99',
#  '8fbaff2f-7ff3-472e-977f-b5b9df84376f',
#  '7089023d-f5ba-4f88-9de4-d1800e2111cb',
#  '2287e9c0-530e-4d0c-9cf6-4e6faf05dec3',
#  '6e3a6abd-fefd-4314-88b5-5fd2102b5b7d',
#  '9aa3e93c-545d-43e0-9f5d-fd454259436f',
#  'ae2dcde7-ec6b-416a-849d-3e4c504c5987',
#  'b63c4e6b-4e9b-4763-a715-073c728b1d11',
#  '35050a13-3e21-4231-9643-ab78b3109d05',
#  '9f98f90e-6ddd-47ff-8739-269c901c481d',
#  '7b3c4619-3ebd-472c-aed3-f5ca0280148f',
#  '657037cb-00db-41a5-8aa8-a3f7f6d11944',
#  '041f6325-95c6-4b8e-8ebf-17fa6fe0395b',
#  '2a0f0df6-494c-4ad7-bb3d-85444a5b086d',
#  '2f28c323-561f-4913-8a4c-609439c26828',
#  'c452cfad-9e60-425f-8baa-e59d5dfc618b',
#  'abc48c7a-61b9-4e59-b915-a0a6a9737962',
#  '5c68df76-1a92-4d34-b159-0aa6d13400b2',
#  'e98308f4-e1f7-43c3-91e5-d7bdafb6dcff',
#  'cd18aabc-c21e-4859-aa3c-1f9f4f3b916d',
#  'b84dd1c2-87a2-4210-b4ae-f0b2bbff512a',
#  '61a227f3-949d-4e74-8787-cb90a5d991fe',
#  '82e6a4aa-ba7c-43e3-beb6-49f9a579c1c6',
#  '7a5475c3-c43b-4c66-94be-bbad161933f1',
#  '0f1d3c59-f041-4c2f-b96c-e53ffe51ae72',
#  '14de72ca-7142-4cf3-b506-3e4fe2879717',
#  'bff7a1a6-f1b2-40b3-8b72-23dd8b1a6493',
#  'a139554e-7514-480c-a9d3-527438ceedc1',
#  '27a30692-1990-4264-bb7c-eaa35ba36f15',
#  'b23495d0-48ee-4549-ac64-a60dcf5e340f',
#  '6a70e3ed-ad14-4ccd-a997-e023bb990dba',
#  '3ceb2ac0-8a2c-4053-91b9-5448da4ff8bf',
#  'db27517a-92f6-45a1-8ec7-1384a556b392',
#  'ecc95388-32aa-4bd2-a0e3-3259ced5512e',
#  '4c0f2b9a-83d5-4ef7-9f08-9aa5c1339547',
#  '9f6fd103-903c-479c-bd17-4ae0ada45dcd',
#  'd675ad82-4026-4934-b320-d05092a66e3c',
#  'b9919d49-70e9-4401-9004-f933b9bc2245',
#  '199a0a21-2c68-4a4e-bb45-9ec2e283b242',
#  '48839909-ce6c-4ac5-a3f9-887044ae6d87',
#  '62ac5ed0-9f40-4f83-9132-d116846c4f9e',
#  'c53bd577-b4ef-4ff3-95f8-eb401e0c66d8',
#  'eeb2c224-a077-4b3f-adcd-b9e8de9ab389',
#  'bd8cde3d-66e3-4bc2-85b9-2f588417c5a1',
#  '8415b662-1488-4105-9f22-b6755ae54d0d',
#  'c269ac8a-20f6-4e47-a6da-6b5ad57d2953',
#  'e1ca3139-bd04-4dd0-9595-a7663af9729b',
#  '27b19387-dc36-4b65-a2d8-abdc7e1c9ca7',
#  '9f38e9eb-022a-4775-9315-420a3f879a62',
#  '0487588a-fac6-44be-8e89-06c77ec563a5',
#  'd3d60624-7570-4542-9591-2d1860fef69f',
#  'a38d0db5-8dee-44bf-accc-a934f514eee5',
#  'e6cb0162-9246-40f0-968a-c8b27a18ed52',
#  'c238def9-343f-4ba2-a8fc-81950d810f1e',
#  '274a06ff-78ab-40cd-af07-5e7b2aaa3c6c',
#  '6ec84819-430a-4e00-9b39-ab199bb8e988',
#  'dc883fe0-97a2-4ac9-b890-c44eee31f3d9',
#  '176d3919-b5c5-4473-9518-0d9989f71d95',
#  '40931e46-8eaa-4e39-a965-4f683431738e',
#  '0e510293-c597-4075-bc25-c2246df3dd1b',
#  '2d267a4e-377a-4ae1-9045-4253617a988c',
#  '1de9bd72-93d8-49ea-868e-73adafa7fa65',
#  'afecf5ac-cb98-4150-ad18-06e2ed3dfa0e',
#  'db05428a-704a-4b23-9c51-10160d9cc28c',
#  '1a766f87-0bbf-451b-ba6f-efeef73135f9',
#  'f462319d-92de-4ecc-a4c7-a11abce1893c',
#  'd47dbd29-d631-4449-8af9-3c9e5e633913',
#  '8c982365-b56e-4538-87c0-2e559a88c71c',
#  'a7eb6bba-4c20-451c-8ceb-5b58cd77d35e',
#  'e4c0a0d2-acb2-411f-a42a-31b9d2594948',
#  'b711647e-c085-4f0f-aade-c533fa1bbe33',
#  'ba2fcfbb-1dbb-4b1b-a53b-75eea4c8c30c',
#  '27ba4a43-a445-48cb-b6a1-46a313e73aed',
#  '5365b89a-d8a7-4c94-bb01-6a59b0ee2845',
#  '5ca163ee-a8c3-4b1d-a212-7e0572564e82',
#  'd61bafda-7b4f-45b0-a5d8-49491da3cf9a',
#  'a5c6a3f2-b19e-4a80-af8f-87aa5778b4ea',
#  'fe46c77c-0159-4df4-942e-bfb8e54155a0',
#  'ccb98da0-e033-4d82-b283-a49bdebfb073',
#  'd70c49b2-b709-472b-998c-6d1496bce372',
#  '6b2389dd-82c7-492f-9790-28cd813a174b',
#  'a0f514a4-959c-4b26-bf03-f7fb0cb8b20c',
#  '1882ac8a-4a02-470c-86f5-541623853854',
#  '4763003c-2edf-4664-9de2-df80539762b1',
#  '09d4f046-cf71-4691-87a2-ca129bff3614',
#  'da46e478-4695-497a-8731-a89fe3f16240',
#  '2007b871-2dee-468d-b9ab-20fffaa4bcc7',
#  'a6fae844-c47f-4fdb-bf52-695ac663adac',
#  '254b69f0-3cfa-48e7-b767-249182c3d87e',
#  '6f70b701-f78c-4348-96e0-6ce46e6e6354',
#  '207b852e-ff90-4e4d-87b2-a8417c2ec0fd',
#  '83be8959-cf76-4fa9-b1bb-5aaff8d2d9c7',
#  'ad24c550-9733-46b6-a53b-d9bbe32a7ad6',
#  '337d9ae0-463f-4be3-b547-75fc7af1b6c9',
#  '12523ca0-e716-4e0a-9f4a-af68d250fd81',
#  '21761ea4-9f5e-46e2-9dcc-2fefb0f266b4',
#  '021f0b6b-ba47-4b04-bcdd-0cdcc249ab28',
#  '390524ad-670a-4492-9ac5-a8efcd4eb343',
#  'e9aeea7e-8811-4c94-a7e3-93782cd4264d',
#  '6a04d40e-abc2-435f-9b7d-c93197ec4302',
#  '37f60b64-137f-4db1-bbdc-f2dd3caf9514',
#  '64ac91d0-89d1-4548-8139-523d135b3beb',
#  '78a84f12-650e-4a0e-b28d-ea9676ca65ec',
#  'a739a1cd-59ab-4b55-be03-34b0e9f863b2',
#  'b60fc5eb-736c-4c9f-8c01-16a86a4e1bc3',
#  'ef05e49c-e9a8-49d5-b52b-55f2d49b793b',
#  '454b1794-4230-4738-9d85-836196fd42c0',
#  '63ee9633-a859-42d6-ad95-39f4138a0b63',
#  'ee809c6f-ca86-43a8-8498-f1f74d456edc',
#  'ad872c8b-faac-4a1b-8df7-53c7a2a52c12',
#  '97ec1ce3-ada8-490d-aa95-1991b8b6770f',
#  'eec5464c-e3a6-458c-a334-f7a2267986d9',
#  '4e2fa9db-d20a-4198-9482-e9fa5e981a2d',
#  'f951ce97-6312-4dd3-ab9e-a4ea65e6f854',
#  '0f5e8738-b2b4-4991-9bce-4f722b85d28b',
#  '65a5808c-6693-479c-bdd5-9331360d3af2',
#  '17f3aa5a-f58c-4385-af74-354e4791c87b',
#  '788591bf-41a8-417d-81e0-17ca63156f4e',
#  '1e26c6d6-fd1a-4ff5-9e9c-95f32b29fa41',
#  '52c89281-00d3-4b75-8be4-ac0f172342ef',
#  'cba78f08-2e49-4a9f-ba84-1c2859b7982a',
#  '91b004ba-d27e-49cd-a014-3a022d39c7d4',
#  '9181a2ac-f3c2-40c3-9cdc-df8da3af5ae2',
#  '71bdb71c-ddd3-4869-b9d6-9d1077066dc4',
#  'cab309b6-3580-4cff-a8b3-761c6e888e30',
#  'af701611-031f-454e-91ed-9e36a6896130',
#  '019a90ed-8f12-4358-9b64-bea1e17bc9ef',
#  '4d4ae8ef-fe8b-4ef3-9d13-2abbfcf8880e',
#  '5b9d7974-f6d4-46fb-9d6a-340df9afe7a4',
#  '4e5af36c-fc9c-47b1-bbda-fcd1415e5068',
#  '38f284a0-b6d1-4260-b2f5-fc47af68113c',
#  'b01dfe3f-35f7-47d3-90ec-5eaf315b6f92',
#  'e6f81842-d20c-4cc1-8b2b-68cc294d3623',
#  '5a7ac4f7-761a-43f2-9c16-9a15c8101c88',
#  '115e9b1f-a98d-48b6-8d2b-527ce1d5f3dc',
#  '84ce61a1-0005-4a7a-a9ae-4c15fe20c16d',
#  'b8e53a7b-0dc2-458b-9214-09f37e1aceed',
#  '45a28038-afff-4f71-965f-9a76da32061a',
#  '43e0180a-37c6-40c5-bb2d-045bf3844fc4',
#  '9e282c5f-6b58-4504-9067-eaa1eeedb569',
#  '05c91e9d-36e7-4973-842b-41359a0699ce',
#  '1d93a074-f602-4455-9554-7746b7e381f7',
#  '52ee60c6-9837-4dbc-b3e5-672421a23698',
#  'f4f7c5a4-672a-4bad-bc61-d49cffdc74a4',
#  '52fb8c31-bd78-466f-aae2-965b5050c34d',
#  '2ee86b8e-a3b6-455e-a24f-fb1cd6f51fb7',
#  '65c73935-1ae6-4730-87a9-76f9a37ee578',
#  '5837be10-930a-4800-af22-5c0a5639a00e',
#  'd934ab04-bebe-44a7-91f0-0bd832aeea12',
#  '30d28b20-55db-400c-a766-b346115c06bc',
#  'a5146198-fb0b-4e00-a458-a6daf1600858',
#  '9d697952-b724-49e5-a464-5229b3d8e868',
#  'c13236bc-bd21-4b39-ab88-acfa0d1c490c',
#  'c39918f4-6c51-4650-8502-a4f41c377ff4',
#  'a2f64283-db31-4a8a-89c4-5eede794ca6b',
#  '7bc5110f-3db4-409b-9127-3afd2aff7e5f',
#  '3ff61b3d-81c1-4938-b4fa-a976987f4171',
#  'de087731-0e30-4b02-85e6-0319b96bd2a8',
#  '5772ae3c-2369-48c2-8b38-28d0bac21e0a',
#  'd593f828-3a98-4bc8-9cc8-606c372ab4b3',
#  '6608e00a-5c82-4534-8733-08bdead6132e',
#  'd2b714c2-8e23-4f41-88f2-98471b0ffd06',
#  'c3042cd4-cc21-4af1-97cc-704de5bb38ef',
#  'aa35d612-73e4-40fa-8033-879d365b1f30',
#  '96e3a733-dc65-460d-aba1-5eacda62ef57',
#  'b1207d30-82d9-477f-ba13-7dc32194bfd6',
#  '45dc2d4a-8e16-48f1-9b2f-538ec52b71d9',
#  'e6845254-6948-4caa-9828-6f980aa7e302',
#  '5e77df70-d7be-4fe5-a581-1bdc83363622',
#  '78cc57ec-a4e9-4182-a373-724e9d251291',
#  '717d9359-ed13-4bdd-a5b5-0fdcb2a17705',
#  'ceb67a82-3eb4-4a6e-be61-2930ccd115de',
#  '64a36649-301d-4345-9827-06f061c81a07']

# %%
## Source Dir for large tiles, relative path
long_list = glob.glob('../my-private-bucket/sq_km_tiles_norm/*')
test_list = glob.glob('../my-private-bucket/test-input-sm-tiles/*')

# %%
files = list()
for file in long_list:
    files.append(str.split(file, '/')[3])

# %%
files
# Out:
# ['TEAK_large_001.las',
#  'TEAK_large_002.las',
#  'TEAK_large_003.las',
#  'TEAK_large_004.las',
#  'TEAK_large_005.las',
#  'TEAK_large_006.las',
#  'TEAK_large_007.las',
#  'TEAK_large_008.las',
#  'TEAK_large_009.las',
#  'TEAK_large_010.las',
#  'TEAK_large_011.las',
#  'TEAK_large_012.las',
#  'TEAK_large_013.las',
#  'TEAK_large_014.las',
#  'TEAK_large_015.las',
#  'TEAK_large_016.las',
#  'TEAK_large_017.las',
#  'TEAK_large_018.las',
#  'TEAK_large_019.las',
#  'TEAK_large_020.las',
#  'TEAK_large_021.las',
#  'TEAK_large_022.las',
#  'TEAK_large_023.las',
#  'TEAK_large_024.las',
#  'TEAK_large_025.las',
#  'TEAK_large_026.las',
#  'TEAK_large_027.las',
#  'TEAK_large_028.las',
#  'TEAK_large_029.las',
#  'TEAK_large_030.las',
#  'TEAK_large_031.las',
#  'TEAK_large_032.las',
#  'TEAK_large_033.las',
#  'TEAK_large_034.las',
#  'TEAK_large_035.las',
#  'TEAK_large_036.las',
#  'TEAK_large_037.las',
#  'TEAK_large_038.las',
#  'TEAK_large_039.las',
#  'TEAK_large_040.las',
#  'TEAK_large_041.las',
#  'TEAK_large_042.las',
#  'TEAK_large_043.las',
#  'TEAK_large_044.las',
#  'TEAK_large_045.las',
#  'TEAK_large_046.las',
#  'TEAK_large_047.las',
#  'TEAK_large_048.las',
#  'TEAK_large_049.las',
#  'TEAK_large_050.las',
#  'TEAK_large_051.las',
#  'TEAK_large_052.las',
#  'TEAK_large_053.las',
#  'TEAK_large_054.las',
#  'TEAK_large_055.las',
#  'TEAK_large_056.las',
#  'TEAK_large_057.las',
#  'TEAK_large_058.las',
#  'TEAK_large_059.las',
#  'TEAK_large_060.las',
#  'TEAK_large_061.las',
#  'TEAK_large_062.las',
#  'TEAK_large_063.las',
#  'TEAK_large_064.las',
#  'TEAK_large_065.las',
#  'TEAK_large_066.las',
#  'TEAK_large_067.las',
#  'TEAK_large_068.las',
#  'TEAK_large_069.las',
#  'TEAK_large_070.las',
#  'TEAK_large_071.las',
#  'TEAK_large_072.las',
#  'TEAK_large_073.las',
#  'TEAK_large_074.las',
#  'TEAK_large_075.las',
#  'TEAK_large_076.las',
#  'TEAK_large_077.las',
#  'TEAK_large_078.las',
#  'TEAK_large_079.las',
#  'TEAK_large_080.las',
#  'TEAK_large_081.las',
#  'TEAK_large_082.las',
#  'TEAK_large_083.las',
#  'TEAK_large_084.las',
#  'TEAK_large_085.las',
#  'TEAK_large_086.las',
#  'TEAK_large_087.las',
#  'TEAK_large_088.las',
#  'TEAK_large_089.las',
#  'TEAK_large_090.las',
#  'TEAK_large_091.las',
#  'TEAK_large_092.las',
#  'TEAK_large_093.las',
#  'TEAK_large_094.las',
#  'TEAK_large_095.las',
#  'TEAK_large_096.las',
#  'TEAK_large_097.las',
#  'TEAK_large_098.las',
#  'TEAK_large_099.las',
#  'TEAK_large_100.las',
#  'TEAK_large_101.las',
#  'TEAK_large_102.las',
#  'TEAK_large_103.las',
#  'TEAK_large_104.las',
#  'TEAK_large_105.las',
#  'TEAK_large_106.las',
#  'TEAK_large_107.las',
#  'TEAK_large_108.las',
#  'TEAK_large_109.las',
#  'TEAK_large_110.las',
#  'TEAK_large_111.las',
#  'TEAK_large_112.las',
#  'TEAK_large_113.las',
#  'TEAK_large_114.las',
#  'TEAK_large_115.las',
#  'TEAK_large_116.las',
#  'TEAK_large_117.las',
#  'TEAK_large_118.las',
#  'TEAK_large_119.las',
#  'TEAK_large_120.las',
#  'TEAK_large_121.las',
#  'TEAK_large_122.las',
#  'TEAK_large_123.las',
#  'TEAK_large_124.las',
#  'TEAK_large_125.las',
#  'TEAK_large_126.las',
#  'TEAK_large_127.las',
#  'TEAK_large_128.las',
#  'TEAK_large_129.las',
#  'TEAK_large_130.las',
#  'TEAK_large_131.las',
#  'TEAK_large_132.las',
#  'TEAK_large_133.las',
#  'TEAK_large_134.las',
#  'TEAK_large_135.las',
#  'TEAK_large_136.las',
#  'TEAK_large_137.las',
#  'TEAK_large_138.las',
#  'TEAK_large_139.las',
#  'TEAK_large_140.las',
#  'TEAK_large_141.las',
#  'TEAK_large_142.las',
#  'TEAK_large_143.las',
#  'TEAK_large_144.las',
#  'TEAK_large_145.las',
#  'TEAK_large_146.las',
#  'TEAK_large_147.las',
#  'TEAK_large_148.las',
#  'TEAK_large_149.las',
#  'TEAK_large_150.las',
#  'TEAK_large_151.las',
#  'TEAK_large_152.las',
#  'TEAK_large_153.las',
#  'TEAK_large_154.las',
#  'TEAK_large_155.las',
#  'TEAK_large_156.las',
#  'TEAK_large_157.las',
#  'TEAK_large_158.las',
#  'TEAK_large_159.las',
#  'TEAK_large_160.las',
#  'TEAK_large_161.las',
#  'TEAK_large_162.las',
#  'TEAK_large_163.las',
#  'TEAK_large_164.las',
#  'TEAK_large_165.las',
#  'TEAK_large_166.las',
#  'TEAK_large_167.las',
#  'TEAK_large_168.las',
#  'TEAK_large_169.las',
#  'TEAK_large_170.las',
#  'TEAK_large_171.las',
#  'TEAK_large_172.las',
#  'TEAK_large_173.las',
#  'TEAK_large_174.las',
#  'TEAK_large_175.las',
#  'TEAK_large_176.las',
#  'TEAK_large_177.las',
#  'TEAK_large_178.las',
#  'TEAK_large_179.las',
#  'TEAK_large_180.las',
#  'TEAK_large_181.las',
#  'TEAK_large_182.las',
#  'TEAK_large_183.las',
#  'TEAK_large_184.las',
#  'TEAK_large_185.las',
#  'TEAK_large_186.las',
#  'TEAK_large_187.las',
#  'TEAK_large_188.las',
#  'TEAK_large_189.las',
#  'TEAK_large_190.las',
#  'TEAK_large_191.las',
#  'TEAK_large_192.las',
#  'TEAK_large_193.las',
#  'TEAK_large_194.las',
#  'TEAK_large_195.las',
#  'TEAK_large_196.las',
#  'TEAK_large_197.las',
#  'TEAK_large_198.las',
#  'TEAK_large_199.las',
#  'TEAK_large_200.las',
#  'TEAK_large_201.las',
#  'TEAK_large_202.las',
#  'TEAK_large_203.las',
#  'TEAK_large_204.las',
#  'TEAK_large_205.las',
#  'TEAK_large_206.las',
#  'TEAK_large_207.las',
#  'TEAK_large_208.las',
#  'TEAK_large_209.las',
#  'TEAK_large_210.las',
#  'TEAK_large_211.las',
#  'TEAK_large_212.las',
#  'TEAK_large_213.las',
#  'TEAK_large_214.las',
#  'TEAK_large_215.las',
#  'TEAK_large_216.las',
#  'TEAK_large_217.las',
#  'TEAK_large_218.las',
#  'TEAK_large_219.las',
#  'TEAK_large_220.las',
#  'TEAK_large_221.las',
#  'TEAK_large_222.las',
#  'TEAK_large_223.las',
#  'TEAK_large_224.las',
#  'TEAK_large_225.las',
#  'TEAK_large_226.las',
#  'TEAK_large_227.las',
#  'TEAK_large_228.las',
#  'TEAK_large_229.las',
#  'TEAK_large_230.las',
#  'TEAK_large_231.las',
#  'TEAK_large_232.las',
#  'TEAK_large_233.las',
#  'TEAK_large_234.las',
#  'TEAK_large_235.las',
#  'TEAK_large_237.las',
#  'TEAK_large_238.las',
#  'TEAK_large_239.las',
#  'TEAK_large_240.las',
#  'TEAK_large_241.las',
#  'TEAK_large_242.las',
#  'TEAK_large_243.las',
#  'TEAK_large_244.las',
#  'TEAK_large_245.las',
#  'TEAK_large_246.las',
#  'TEAK_large_247.las',
#  'TEAK_large_248.las',
#  'TEAK_large_249.las']

# %%
test_file = "s3://maap-ops-workspace/jclayton0/normalized/norm_TEAK_047_lidar_2021.las"
url = build_file_url(files[145])

# %% [markdown]
# ## Get JobIDs from previous submissions

# %%
## Get the failed job IDs, find the submission parameter locations,
# and scrape the input file s3 url from the parameter JSON

failed_job_ids = get_failed_jobs_in_list(old_jobs)
failed_job_urls = [job_result_for(job) for job in failed_job_ids]
failed_params = [to_failed_job_params(url) for url in failed_job_urls]
failed_inputs = [get_failed_job_input_LAS(json) for json in failed_params]

failed_inputs
# Out:
# ['s3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_008.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_009.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_010.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_011.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_012.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_013.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_014.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_055.las',
#  's3://maap-ops-workspace/jclayton0/sq_km_tiles_norm/TEAK_large_097.las']

# %%
# resubmit_kwargs = [get_split_kwargs(url) for url in failed_inputs]
# resubmit_kwargs

# %%
failed_tiles = [tile.split('_norm/')[1] for tile in failed_inputs]
failed_tiles
#save them to a txtfile

# %% [markdown]
# ## Run Split on all files and collect the outputs

# %%
start_time = datetime.datetime.now()

# Set up output directory
output_dir = Path(f"/projects/my-private-bucket/run_output_"
                      f"{start_time.strftime('%Y%m%d_%H%M%S')}")
os.makedirs(output_dir, exist_ok=False)

# Set up log
logging.basicConfig(filename=output_dir / "run.log",
                        level=logging.INFO,
                        format='%(asctime)s - %(message)s',
                        datefmt='%Y-%m-%d %H:%M:%S')

log_and_print(f"Starting new model run at MAAP at {start_time}.")
# Out:
# Starting new model run at MAAP at 2024-11-15 13:10:05.350759.

# %%
    # Submit jobs for each pair of granules
username = "jclayton0"
job_limit = 1000
check_interval = 90 #seconds between updates

##### REMOVE this block if doing new run
start_time = datetime.datetime.now()
log_and_print(f"Starting new model run at MAAP at {start_time}.")
output_dir = old_output_dir 
files = failed_inputs
######


    if job_limit:
        n_jobs = min(len(files), job_limit)
    else:
        n_jobs = len(files)
    log_and_print(f"Submitting {n_jobs} "
                  f"jobs.")

    job_kwargs_list = []
    for file in files:
        
        #job_kwargs = get_split_kwargs(build_file_url(file))
        job_kwargs = get_split_kwargs(build_file_url(file))

        job_kwargs_list.append(job_kwargs)

    jobs = []
    for job_kwargs in job_kwargs_list[:job_limit]:
        job = maap.submitJob(**job_kwargs)
        jobs.append(job)

    print(f"Submitted {len(jobs)} jobs.")

    job_ids = [job.id for job in jobs]

    # Write job IDs to a file in case processing is interrupted
    job_ids_file = output_dir / "job_ids.txt"
    with open(job_ids_file, 'w') as f:
        for job_id in job_ids:
            f.write(f"{job_id}\n")
    log_and_print(f"Job IDs written to {job_ids_file}")

    # Give the jobs time to start
    click.echo("Waiting for jobs to start...")
    time.sleep(10)

    # Initialize job states
    final_states = ["Succeeded", "Failed", "Deleted"]

    job_states = {job_id: "" for job_id in job_ids}
    update_job_states(job_states, final_states, batch_size=50, delay=10)

    known_completed = len([state for state in job_states.values()
                           if state in final_states])

    while True:
        try:
            with tqdm(total=len(job_ids), desc="Jobs Completed", unit="job") as pbar:
                while any(state not in final_states for state in job_states.values()):

                    # Update the job states
                    n_new_completed: int = update_job_states(job_states,
                                                             final_states,
                                                             batch_size = 50,
                                                             delay = 10)

                    # Update the progress bar
                    pbar.update(n_new_completed)
                    last_updated = datetime.datetime.now()
                    known_completed += n_new_completed
                    
                    status_counts = {status: list(job_states.values()).count(status)
                                     for status in final_states + ["Accepted", "Running"]}
                    status_counts["Other"] = len(job_states) - sum(status_counts.values())
                    status_counts["Last updated"] = last_updated.strftime("%H:%M:%S")

                    pbar.set_postfix(status_counts, refresh=True)

                    if known_completed == len(job_ids):
                        break

                    time.sleep(check_interval)

        except KeyboardInterrupt:
            print("Are you sure you want to cancel the process?")
            print("Press Ctrl+C again to confirm, or wait to continue.")
            try:
                time.sleep(3)
                print("Continuing...")
            except KeyboardInterrupt:
                print("Model run aborted.")
                pending_jobs = [job_id for job_id, state in job_states.items()
                                if state not in final_states]
                click.echo(f"Cancelling {len(pending_jobs)} pending jobs.")
                for job_id in pending_jobs:
                    maap.cancelJob(job_id)
                break
        else:
            break

    # Process the results once all jobs are completed
    succeeded_job_ids = get_succeeded_jobs_in_list(job_ids)
    
    failed_job_ids = get_failed_jobs_in_list(job_ids)

    other_job_ids = get_other_status_jobs_in_list(job_ids) 

    click.echo(f"Processing results for {len(succeeded_job_ids)} "
               f"succeeded jobs.")

    click.echo(f"Gathering tarball paths from succeeded jobs.")

    tar_paths = []
    for job_id in tqdm(succeeded_job_ids):
        job_result_url = job_result_for(job_id)
        time.sleep(1) # to avoid overwhelming the API
        job_output_dir = to_job_output_dir(job_result_url, username)
        # Find .tar.gz file in the output dir
        tar_file = [f for f in os.listdir(job_output_dir)
                     if f.endswith('.tar.gz')]
        if len(tar_file) > 1:
            warnings.warn(f"Multiple .tar.gz files found in "
                          f"{job_output_dir}.")
        if len(tar_file) == 0:
            warnings.warn(f"No .tar.gz files found in "
                          f"{job_output_dir}.")
        if tar_file:
            tar_paths.append(os.path.join(job_output_dir, tar_file[0]))

    # Log the succeeded and failed job IDs
    logging.info(f"{len(succeeded_job_ids)} jobs succeeded.")
    logging.info(f"Succeeded job IDs: {succeeded_job_ids}\n")
    logging.info(f"{len(failed_job_ids)} jobs failed.")
    logging.info(f"Failed job IDs: {failed_job_ids}\n")
    logging.info(f"{len(other_job_ids)} jobs in other states.")
    logging.info(f"Other job IDs: {other_job_ids}\n")

    # Copy all tarballs to the output directory
    click.echo(f"Copying {len(tar_paths)} Tarballs to {output_dir}.")
    copy_batch_count = 0
    for tar_path in tqdm(tar_paths):
        try:
            shutil.copy(tar_path, output_dir)
            copy_batch_count += 1
            if copy_batch_count == 50:
                time.sleep(60)
                copy_batch_count = 0
            else:
                time.sleep(2)
            
        except Exception as e:
            warnings.warn(f"Error copying {tar_path} to {output_dir}: {str(e)}")
            click.echo("Retrying in 10 seconds.")
            time.sleep(10)
            try:
                shutil.copy(tar_path, output_dir)
            except Exception as e:
                click.echo(f"Retry failed: {str(e)}")
                click.echo(f"Skipping {tar_path}.")
                continue

    # Compress the output directory
    # click.echo(f"Compressing output directory.")
    # shutil.make_archive(output_dir, 'zip', output_dir)
    # click.echo(f"Output directory compressed to {output_dir}.zip.")

    end_time = datetime.datetime.now()

    log_and_print(f"Model run completed at {end_time}.")
    
# if __name__ == "__main__":
#     main()
# Out:
# Starting new model run at MAAP at 2024-11-19 15:29:05.771577.
# Submitting 9 jobs.
# Submitted 9 jobs.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 39
#      36 job_ids = [job.id for job in jobs]
#      38 # Write job IDs to a file in case processing is interrupted
# ---> 39 job_ids_file = output_dir / "job_ids.txt"
#      40 with open(job_ids_file, 'w') as f:
#      41     for job_id in job_ids:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
new_job_ids = job_ids
new_job_ids
# Out:
# ['a39f19f7-b9dc-4f81-aaf9-d2a7d7d4bf0b',
#  '43bb3357-a447-41a6-8d18-2c24947e349e',
#  '886c04df-acbc-4e3e-8807-356951c86da9',
#  '0e238056-d343-4924-b8ff-7e04d0fb7224',
#  '7af49420-7269-4955-b6f9-2565849d8be1',
#  '96001cf0-2a46-469f-9f40-d7335e8823d5',
#  'cf180c75-0169-4c11-a8dc-96ae5bb1d4be',
#  '7737a35c-5724-40b4-a352-b479b14df366',
#  '668f99ba-5fca-4980-a82b-276d06681ca5']

# %%
# comment out if doing new stuff
job_ids = old_jobs
output_dir = old_output_dir
username = "jclayton0"

# Process the results once all jobs are completed
succeeded_job_ids = [job_id for job_id in job_ids
                     if job_status_for(job_id) == "Succeeded"]

failed_job_ids = [job_id for job_id in job_ids
                  if job_status_for(job_id) == "Failed"]

other_job_ids = [job_id for job_id in job_ids
                 if job_status_for(job_id)
                 not in ["Succeeded", "Failed"]]

click.echo(f"Processing results for {len(succeeded_job_ids)} "
           f"succeeded jobs.")

click.echo(f"Gathering tarball paths from succeeded jobs.")

tar_paths = []
for job_id in tqdm(succeeded_job_ids):
    job_result_url = job_result_for(job_id)
    time.sleep(1) # to avoid overwhelming the API
    job_output_dir = to_job_output_dir(job_result_url, username)
    # Find .tar.gz file in the output dir
    tar_file = [f for f in os.listdir(job_output_dir)
                 if f.endswith('.tar.gz')]
    if len(tar_file) > 1:
        warnings.warn(f"Multiple .tar.gz files found in "
                      f"{job_output_dir}.")
    if len(tar_file) == 0:
        warnings.warn(f"No .tar.gz files found in "
                      f"{job_output_dir}.")
    if tar_file:
        tar_paths.append(os.path.join(job_output_dir, tar_file[0]))

# Log the succeeded and failed job IDs
logging.info(f"{len(succeeded_job_ids)} jobs succeeded.")
logging.info(f"Succeeded job IDs: {succeeded_job_ids}\n")
logging.info(f"{len(failed_job_ids)} jobs failed.")
logging.info(f"Failed job IDs: {failed_job_ids}\n")
logging.info(f"{len(other_job_ids)} jobs in other states.")
logging.info(f"Other job IDs: {other_job_ids}\n")
# Out:
# Processing results for 239 succeeded jobs.
# Gathering tarball paths from succeeded jobs.
# 100%|██████████| 239/239 [04:49<00:00,  1.21s/it]

# %%
## pickle tarpaths 

import pickle

# with open('tar_paths_step_1.pkl', 'wb') as f:
#    pickle.dump(tar_paths, f)
with open('tar_paths_step_1.pkl', 'rb') as f:
    tar_paths = pickle.load(f)

# %%
tar_paths = tar_paths[-18:]

# %%
output_dir = old_output_dir
outdir_files = os.listdir(output_dir)
# Copy all tarballs to the output directory
click.echo(f"Copying {len(tar_paths)} Tarballs to {output_dir}.")
copy_batch_count = 0
for tar_path in tqdm(tar_paths):
    fname = tar_path.split('/')[-1]
    if fname in outdir_files:
        copy_batch_count +=1
        continue
    else:
        try:
            shutil.copy(tar_path, output_dir)
            copy_batch_count += 1
            if copy_batch_count == 10:
                time.sleep(60)
                copy_batch_count = 0
            else:
                time.sleep(2)
            
        except Exception as e:
            warnings.warn(f"Error copying {tar_path} to {output_dir}: {str(e)}")
            click.echo("Retrying in 10 seconds.")
            time.sleep(10)
            try:
                shutil.copy(tar_path, output_dir)
            except Exception as e:
                click.echo(f"Retry failed: {str(e)}")
                click.echo(f"Skipping {tar_path}.")
                continue


# Compress the output directory
# click.echo(f"Compressing output directory.")
# shutil.make_archive(output_dir, 'zip', output_dir)
# click.echo(f"Output directory compressed to {output_dir}.zip.")

end_time = datetime.datetime.now()

log_and_print(f"Model run completed at {end_time}.")
# Out:
# Copying 18 Tarballs to ../my-private-bucket/run_output_20241115_131005/.
# 100%|██████████| 18/18 [02:16<00:00,  7.56s/it]
# Model run completed at 2024-11-22 15:07:52.852485.

# %% [markdown]
# ## Above, split all files in the directory by submitting a split job then gather the results into a single directory
#
# ## This has to be run several times. You also need, in the terminal, to type
#
# `ls -lhS | tac`
#
# # and remove any files that have a size of 0; they need to be re-transferred

# %% [markdown]
# ## Then, run extract_tarballs.sh after modifying it to include the correct dir
# ectory path.
#
# ## It will take some TIME

# %%
# Directory containing your files
output_dir = old_output_dir

import os
import pickle
# Specify the directory to scan


# List directories that start with 'TEAK'
teak_directories = [
    name for name in os.listdir(output_dir) 
    if os.path.isdir(os.path.join(output_dir, name)) and name.startswith('TEAK')
]

print("Directories starting with 'TEAK':", len(teak_directories))

#path = teak_directories[19]
print(teak_directories[221:])
# Out:
# Directories starting with 'TEAK': 239
# ['TEAK_large_231', 'TEAK_large_232', 'TEAK_large_233', 'TEAK_large_234', 'TEAK_large_235', 'TEAK_large_237', 'TEAK_large_238', 'TEAK_large_239', 'TEAK_large_240', 'TEAK_large_241', 'TEAK_large_242', 'TEAK_large_243', 'TEAK_large_244', 'TEAK_large_245', 'TEAK_large_246', 'TEAK_large_247', 'TEAK_large_248', 'TEAK_large_249']

# %%
for path in teak_directories[221:]:
    print(f"making kwargs for {path}")
    tiles_path = output_dir + path + '/'
    kwargs_file = 'kwargs/' + path + '.pkl'
    tiles = [name for name in os.listdir(tiles_path) 
    if os.path.isfile(os.path.join(tiles_path, name)) and name.endswith('.rds')]
    
    kwargs_list = []
    for tile in tiles:
        tile_url = tiles_path + tile
        url = local_url_to_s3(tile_url)
        kwargs = get_segment_kwargs(url)
        kwargs_list.append(kwargs)
    
    with open(kwargs_file, 'wb') as f:
            pickle.dump(kwargs_list, f)
    
    print(f"{len(kwargs_list)} kwargs written to {kwargs_file}")
    
#print(f"first item: {kwargs_list[0]}")
# Out:
# making kwargs for TEAK_large_231
# 1600 kwargs written to kwargs/TEAK_large_231.pkl
# making kwargs for TEAK_large_232
# 1197 kwargs written to kwargs/TEAK_large_232.pkl
# making kwargs for TEAK_large_233
# 201 kwargs written to kwargs/TEAK_large_233.pkl
# making kwargs for TEAK_large_234
# 19 kwargs written to kwargs/TEAK_large_234.pkl
# making kwargs for TEAK_large_235
# 5 kwargs written to kwargs/TEAK_large_235.pkl
# making kwargs for TEAK_large_237
# 18 kwargs written to kwargs/TEAK_large_237.pkl
# making kwargs for TEAK_large_238
# 83 kwargs written to kwargs/TEAK_large_238.pkl
# making kwargs for TEAK_large_239
# 14 kwargs written to kwargs/TEAK_large_239.pkl
# making kwargs for TEAK_large_240
# 57 kwargs written to kwargs/TEAK_large_240.pkl
# making kwargs for TEAK_large_241
# 169 kwargs written to kwargs/TEAK_large_241.pkl
# making kwargs for TEAK_large_242
# 136 kwargs written to kwargs/TEAK_large_242.pkl
# making kwargs for TEAK_large_243
# 133 kwargs written to kwargs/TEAK_large_243.pkl
# making kwargs for TEAK_large_244
# 101 kwargs written to kwargs/TEAK_large_244.pkl
# making kwargs for TEAK_large_245
# 245 kwargs written to kwargs/TEAK_large_245.pkl
# making kwargs for TEAK_large_246
# 270 kwargs written to kwargs/TEAK_large_246.pkl
# making kwargs for TEAK_large_247
# 262 kwargs written to kwargs/TEAK_large_247.pkl
# making kwargs for TEAK_large_248
# 47 kwargs written to kwargs/TEAK_large_248.pkl
# making kwargs for TEAK_large_249
# 8 kwargs written to kwargs/TEAK_large_249.pkl

# %%
kwargs_files = [name for name in os.listdir('kwargs/') if name.startswith('TEAK')]
kwargs_tilenames = [name.split('.')[0] for name in kwargs_files]
len(kwargs_tilenames)
# Out:
# 239

# %%
output_dir = old_output_dir

job_ids_dir = output_dir + 'job_ids/'
submitted_jobs = [name for name in os.listdir(job_ids_dir)  if os.path.isfile(os.path.join(job_ids_dir, name))]
submitted_jobs_tilenames = [name.split('_job')[0] for name in submitted_jobs]
submitted_jobs_tilenames
# Out:
# ['TEAK_large_001',
#  'TEAK_large_002',
#  'TEAK_large_003',
#  'TEAK_large_004',
#  'TEAK_large_005',
#  'TEAK_large_006',
#  'TEAK_large_007',
#  'TEAK_large_015',
#  'TEAK_large_016',
#  'TEAK_large_017',
#  'TEAK_large_018',
#  'TEAK_large_019',
#  'TEAK_large_020',
#  'TEAK_large_021',
#  'TEAK_large_022',
#  'TEAK_large_023',
#  'TEAK_large_024',
#  'TEAK_large_025',
#  'TEAK_large_026',
#  'TEAK_large_027',
#  'TEAK_large_028',
#  'TEAK_large_029',
#  'TEAK_large_030',
#  'TEAK_large_031',
#  'TEAK_large_032',
#  'TEAK_large_033',
#  'TEAK_large_034',
#  'TEAK_large_035',
#  'TEAK_large_036',
#  'TEAK_large_037',
#  'TEAK_large_038',
#  'TEAK_large_039',
#  'TEAK_large_040',
#  'TEAK_large_041',
#  'TEAK_large_042',
#  'TEAK_large_043',
#  'TEAK_large_044',
#  'TEAK_large_045',
#  'TEAK_large_046',
#  'TEAK_large_047',
#  'TEAK_large_048',
#  'TEAK_large_049',
#  'TEAK_large_050',
#  'TEAK_large_051',
#  'TEAK_large_052',
#  'TEAK_large_053',
#  'TEAK_large_054',
#  'TEAK_large_056',
#  'TEAK_large_057',
#  'TEAK_large_058',
#  'TEAK_large_059',
#  'TEAK_large_060',
#  'TEAK_large_061',
#  'TEAK_large_062',
#  'TEAK_large_063',
#  'TEAK_large_064',
#  'TEAK_large_065',
#  'TEAK_large_066',
#  'TEAK_large_067',
#  'TEAK_large_068',
#  'TEAK_large_069',
#  'TEAK_large_070',
#  'TEAK_large_071',
#  'TEAK_large_072',
#  'TEAK_large_073',
#  'TEAK_large_074',
#  'TEAK_large_075',
#  'TEAK_large_076',
#  'TEAK_large_077',
#  'TEAK_large_078',
#  'TEAK_large_079',
#  'TEAK_large_080',
#  'TEAK_large_081',
#  'TEAK_large_082',
#  'TEAK_large_083',
#  'TEAK_large_084',
#  'TEAK_large_085',
#  'TEAK_large_086',
#  'TEAK_large_087',
#  'TEAK_large_088',
#  'TEAK_large_089',
#  'TEAK_large_090',
#  'TEAK_large_091',
#  'TEAK_large_092',
#  'TEAK_large_093',
#  'TEAK_large_094',
#  'TEAK_large_095',
#  'TEAK_large_096',
#  'TEAK_large_098',
#  'TEAK_large_099',
#  'TEAK_large_100',
#  'TEAK_large_101',
#  'TEAK_large_102',
#  'TEAK_large_103',
#  'TEAK_large_104',
#  'TEAK_large_105',
#  'TEAK_large_106',
#  'TEAK_large_107',
#  'TEAK_large_108',
#  'TEAK_large_109',
#  'TEAK_large_110',
#  'TEAK_large_111',
#  'TEAK_large_112',
#  'TEAK_large_113',
#  'TEAK_large_114',
#  'TEAK_large_115',
#  'TEAK_large_116',
#  'TEAK_large_117',
#  'TEAK_large_118',
#  'TEAK_large_119',
#  'TEAK_large_120',
#  'TEAK_large_121',
#  'TEAK_large_122',
#  'TEAK_large_123',
#  'TEAK_large_124',
#  'TEAK_large_125',
#  'TEAK_large_126',
#  'TEAK_large_127',
#  'TEAK_large_128',
#  'TEAK_large_129',
#  'TEAK_large_130',
#  'TEAK_large_131',
#  'TEAK_large_132',
#  'TEAK_large_133',
#  'TEAK_large_134',
#  'TEAK_large_135',
#  'TEAK_large_136',
#  'TEAK_large_137',
#  'TEAK_large_138',
#  'TEAK_large_139',
#  'TEAK_large_140',
#  'TEAK_large_141',
#  'TEAK_large_142',
#  'TEAK_large_143',
#  'TEAK_large_144',
#  'TEAK_large_145',
#  'TEAK_large_146',
#  'TEAK_large_147',
#  'TEAK_large_148',
#  'TEAK_large_149',
#  'TEAK_large_150',
#  'TEAK_large_151',
#  'TEAK_large_152',
#  'TEAK_large_153',
#  'TEAK_large_154',
#  'TEAK_large_155',
#  'TEAK_large_156',
#  'TEAK_large_157',
#  'TEAK_large_158',
#  'TEAK_large_159',
#  'TEAK_large_160',
#  'TEAK_large_161',
#  'TEAK_large_162',
#  'TEAK_large_163',
#  'TEAK_large_164',
#  'TEAK_large_165',
#  'TEAK_large_166',
#  'TEAK_large_167',
#  'TEAK_large_168',
#  'TEAK_large_169',
#  'TEAK_large_170',
#  'TEAK_large_171',
#  'TEAK_large_172',
#  'TEAK_large_173',
#  'TEAK_large_174',
#  'TEAK_large_175',
#  'TEAK_large_176',
#  'TEAK_large_177',
#  'TEAK_large_178',
#  'TEAK_large_179',
#  'TEAK_large_180',
#  'TEAK_large_181',
#  'TEAK_large_182',
#  'TEAK_large_183',
#  'TEAK_large_184',
#  'TEAK_large_185',
#  'TEAK_large_186',
#  'TEAK_large_187',
#  'TEAK_large_188',
#  'TEAK_large_189',
#  'TEAK_large_190',
#  'TEAK_large_191',
#  'TEAK_large_192',
#  'TEAK_large_193',
#  'TEAK_large_194',
#  'TEAK_large_195',
#  'TEAK_large_196',
#  'TEAK_large_197',
#  'TEAK_large_198',
#  'TEAK_large_199',
#  'TEAK_large_200',
#  'TEAK_large_201',
#  'TEAK_large_202',
#  'TEAK_large_203',
#  'TEAK_large_204',
#  'TEAK_large_205',
#  'TEAK_large_206',
#  'TEAK_large_207',
#  'TEAK_large_208',
#  'TEAK_large_209',
#  'TEAK_large_210',
#  'TEAK_large_211',
#  'TEAK_large_212',
#  'TEAK_large_213',
#  'TEAK_large_214',
#  'TEAK_large_215',
#  'TEAK_large_216',
#  'TEAK_large_217',
#  'TEAK_large_218',
#  'TEAK_large_219',
#  'TEAK_large_220',
#  'TEAK_large_221',
#  'TEAK_large_222',
#  'TEAK_large_223',
#  'TEAK_large_224',
#  'TEAK_large_225',
#  'TEAK_large_226',
#  'TEAK_large_227',
#  'TEAK_large_228',
#  'TEAK_large_229',
#  'TEAK_large_230']

# %%
len(submitted_jobs)
# Out:
# 221

# %%
import re
# sort the files by their number

# d matches int, + matches consecutive ints
# this only works because we have only one int in the file
def extract_integer(filename):
    match = re.search(r'\d+', filename)
    return int(match.group()) if match else 0  # Return 0 if no match found

# Sort the list using the extracted integers as the key
sorted_filenames = sorted(kwargs_files, key=extract_integer)

sorted_filenames[221:]
# Out:
# ['TEAK_large_231.pkl',
#  'TEAK_large_232.pkl',
#  'TEAK_large_233.pkl',
#  'TEAK_large_234.pkl',
#  'TEAK_large_235.pkl',
#  'TEAK_large_237.pkl',
#  'TEAK_large_238.pkl',
#  'TEAK_large_239.pkl',
#  'TEAK_large_240.pkl',
#  'TEAK_large_241.pkl',
#  'TEAK_large_242.pkl',
#  'TEAK_large_243.pkl',
#  'TEAK_large_244.pkl',
#  'TEAK_large_245.pkl',
#  'TEAK_large_246.pkl',
#  'TEAK_large_247.pkl',
#  'TEAK_large_248.pkl',
#  'TEAK_large_249.pkl']

# %%
fname = 'step2_submit_from_' + str(len(submitted_jobs)) + '.log'

# %%
print(fname)
# Out:
# step2_submit_from_221.log

# %%
# Submit jobs for each tile
username = "jclayton0"
# job_limit = 1000
check_interval = 90 #seconds between updates

##### REMOVE this block if doing new run
start_time = datetime.datetime.now()
logging.basicConfig(filename=fname,
                        level=logging.INFO,
                        format='%(asctime)s - %(message)s',
                        datefmt='%Y-%m-%d %H:%M:%S')
log_and_print(f"Starting new model run at MAAP at {start_time}.")
output_dir = old_output_dir 
# files = failed_inputs
######
## pick up where we left off: don't forget to make sure the newest file in that dir successfully completed.
tile_indexer = len(submitted_jobs)

interval_time = datetime.datetime.now()
kwargs_files = [name for name in os.listdir('kwargs/') if name.startswith('TEAK')]
#kwargs_files = kwargs_files[:2]
kwargs_files = sorted_filenames = sorted(kwargs_files, key=extract_integer)
kwargs_files = kwargs_files[tile_indexer:]

njobs_total = 0
for file in kwargs_files:
    filepath = 'kwargs/' + file
    with open(filepath, 'rb') as f:
        job_kwargs_list = pickle.load(f)

    job_ids_file = file.split('.')[0] + '_job_ids.pkl'
    job_ids_file = output_dir + "job_ids/" + job_ids_file
    jobs = []
    for job_kwargs in job_kwargs_list:
        job = maap.submitJob(**job_kwargs)
        jobs.append(job)

    njobs_batch = len(jobs)
    print(f"Submitted {njobs_batch} jobs for {file}")

    job_ids = [job.id for job in jobs]

    # Write job IDs to a file in case processing is interrupted
    with open(job_ids_file, 'wb') as f:
        pickle.dump(job_ids, f)
        
    log_and_print(f"Job IDs written to {job_ids_file}")
    njobs_total += njobs_batch
    curr_time = datetime.datetime.now()

    batch_interval = curr_time - interval_time
    total_interval = curr_time - start_time

    batch_interval = batch_interval.total_seconds()
    total_interval = total_interval.total_seconds()

    batch_avg = njobs_batch / batch_interval
    total_avg = njobs_total / total_interval

    log_and_print(f"submitted {njobs_batch} in {batch_interval} seconds, {batch_avg} s/job")
    log_and_print(f"submitted {njobs_total} in total in {total_interval} seconds, {total_avg} s/job")
    interval_time = curr_time
# Out:
# Starting new model run at MAAP at 2024-11-22 17:35:49.869633.
# Submitted 1600 jobs for TEAK_large_231.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_231_job_ids.pkl
# submitted 1600 in 175.156437 seconds, 9.134691407316078 s/job
# submitted 1600 in total in 175.157359 seconds, 9.134643323778363 s/job
# Submitted 1197 jobs for TEAK_large_232.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_232_job_ids.pkl
# submitted 1197 in 130.613697 seconds, 9.164429363024615 s/job
# submitted 2797 in total in 305.771056 seconds, 9.147366780196489 s/job
# Submitted 201 jobs for TEAK_large_233.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_233_job_ids.pkl
# submitted 201 in 21.861098 seconds, 9.194414662978046 s/job
# submitted 2998 in total in 327.632154 seconds, 9.15050602756163 s/job
# Submitted 19 jobs for TEAK_large_234.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_234_job_ids.pkl
# submitted 19 in 2.241302 seconds, 8.477215475647636 s/job
# submitted 3017 in total in 329.873456 seconds, 9.145931402252627 s/job
# Submitted 5 jobs for TEAK_large_235.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_235_job_ids.pkl
# submitted 5 in 0.745679 seconds, 6.705298124259903 s/job
# submitted 3022 in total in 330.619135 seconds, 9.140426793506673 s/job
# Submitted 18 jobs for TEAK_large_237.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_237_job_ids.pkl
# submitted 18 in 2.244596 seconds, 8.019260481618964 s/job
# submitted 3040 in total in 332.863731 seconds, 9.132866446179444 s/job
# Submitted 83 jobs for TEAK_large_238.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_238_job_ids.pkl
# submitted 83 in 9.161556 seconds, 9.059596426633206 s/job
# submitted 3123 in total in 342.025287 seconds, 9.130903821155188 s/job
# Submitted 14 jobs for TEAK_large_239.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_239_job_ids.pkl
# submitted 14 in 1.73045 seconds, 8.09038111473894 s/job
# submitted 3137 in total in 343.755737 seconds, 9.12566587943229 s/job
# Submitted 57 jobs for TEAK_large_240.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_240_job_ids.pkl
# submitted 57 in 6.350064 seconds, 8.976287483086786 s/job
# submitted 3194 in total in 350.105801 seconds, 9.122956520220583 s/job
# Submitted 169 jobs for TEAK_large_241.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_241_job_ids.pkl
# submitted 169 in 18.73848 seconds, 9.01887452984447 s/job
# submitted 3363 in total in 368.844281 seconds, 9.117668819162198 s/job
# Submitted 136 jobs for TEAK_large_242.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_242_job_ids.pkl
# submitted 136 in 15.278431 seconds, 8.901437588715753 s/job
# submitted 3499 in total in 384.122712 seconds, 9.109068250044013 s/job
# Submitted 133 jobs for TEAK_large_243.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_243_job_ids.pkl
# submitted 133 in 14.531089 seconds, 9.152789581014884 s/job
# submitted 3632 in total in 398.653801 seconds, 9.11066190988105 s/job
# Submitted 101 jobs for TEAK_large_244.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_244_job_ids.pkl
# submitted 101 in 11.333573 seconds, 8.911576252255136 s/job
# submitted 3733 in total in 409.987374 seconds, 9.105158443245132 s/job
# Submitted 245 jobs for TEAK_large_245.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_245_job_ids.pkl
# submitted 245 in 27.016753 seconds, 9.068447270476952 s/job
# submitted 3978 in total in 437.004127 seconds, 9.102888861276131 s/job
# Submitted 270 jobs for TEAK_large_246.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_246_job_ids.pkl
# submitted 270 in 29.484075 seconds, 9.157485863131198 s/job
# submitted 4248 in total in 466.488202 seconds, 9.106339628284962 s/job
# Submitted 262 jobs for TEAK_large_247.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_247_job_ids.pkl
# submitted 262 in 28.425525 seconds, 9.217068110439472 s/job
# submitted 4510 in total in 494.913727 seconds, 9.112699353356186 s/job
# Submitted 47 jobs for TEAK_large_248.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_248_job_ids.pkl
# submitted 47 in 5.353195 seconds, 8.779803463165456 s/job
# submitted 4557 in total in 500.266922 seconds, 9.109137141791678 s/job
# Submitted 8 jobs for TEAK_large_249.pkl
# Job IDs written to ../my-private-bucket/run_output_20241115_131005/job_ids/TEAK_large_249_job_ids.pkl
# submitted 8 in 1.016903 seconds, 7.867023698425514 s/job
# submitted 4565 in total in 501.283825 seconds, 9.106617393848685 s/job

# %%
## Need to get the failed jobs, remove them from job IDs, 
## save successful job paths to a file
## 
output_dir = old_output_dir

job_ids_dir = output_dir + 'job_ids/'
submitted_jobs = [name for name in os.listdir(job_ids_dir)  if os.path.isfile(os.path.join(job_ids_dir, name))]
# submitted_jobs_tilenames = [name.split('_job')[0] for name in submitted_jobs]
# submitted_jobs_tilenames
gathered_paths = [name for name in os.listdir('seg_out_paths/')]

resubmitted_jobs = []

for file in submitted_jobs[len(gathered_paths):]:
    filepath = job_ids_dir + file
    with open(filepath, 'rb') as f:
        job_ids = pickle.load(f)

    total_jobs = len(job_ids)
    #succeeded = get_succeeded_jobs_in_list(job_ids)
    unsuccessful = get_unsuccessful_jobs_in_list(job_ids)
   # other_status = total_jobs - len(succeeded) - len(failed) #get_other_status_jobs_in_list(job_ids)
    for job in unsuccessful:
        job_ids.remove(job)

    rds_paths = []
    for job_id in tqdm(job_ids):
        job_result_url = job_result_for(job_id)
       # time.sleep(1) # to avoid overwhelming the API
        job_output_dir = to_job_output_dir(job_result_url, username)
        # Find .tar.gz file in the output dir
        rds_file = [f for f in os.listdir(job_output_dir)
                     if f.endswith('.rds')]
        if rds_file:
            rds_paths.append(os.path.join(job_output_dir, rds_file[0]))
        
    tilename = file.split('_job')[0]

    output_paths_file = 'seg_out_paths/' + tilename + 'output_paths.pkl'

    with open(output_paths_file, 'wb') as f:
        pickle.dump(rds_paths, f)

    failed_job_urls = [job_result_for(job) for job in unsuccessful]
    failed_params = [to_failed_job_params(url) for url in failed_job_urls]
    failed_inputs = [get_failed_job_input_LAS(json) for json in failed_params]

    failed_inputs_file = 'failed_inputs/' + tilename + '_failed.pkl'

    with open(failed_inputs_file, 'wb') as f:
        pickle.dump(failed_inputs, f)

    
    print(f"saved {total_jobs} output paths for {tilename} to {output_paths_file} and {len(failed_inputs)} failed filepaths to {failed_inputs_file}")

    
    # if(total_jobs == 0):
    #     print(f"No jobs for {file.split('_job')[0]}")
    #     continue;
    
    # print(f"Of {total_jobs} jobs in {file.split('_job')[0]}, {len(succeeded)/total_jobs}% succeeded, {len(failed)/total_jobs}% failed, and {other_status} jobs had other statuses")

# %%
# gathered_paths = [name for name in os.listdir('seg_out_paths/')]
# submitted_jobs[len(gathered_paths):]
# Out:
# ['TEAK_large_020_job_ids.pkl',
#  'TEAK_large_021_job_ids.pkl',
#  'TEAK_large_022_job_ids.pkl',
#  'TEAK_large_023_job_ids.pkl',
#  'TEAK_large_024_job_ids.pkl',
#  'TEAK_large_025_job_ids.pkl',
#  'TEAK_large_026_job_ids.pkl',
#  'TEAK_large_027_job_ids.pkl',
#  'TEAK_large_028_job_ids.pkl',
#  'TEAK_large_029_job_ids.pkl',
#  'TEAK_large_030_job_ids.pkl',
#  'TEAK_large_031_job_ids.pkl',
#  'TEAK_large_032_job_ids.pkl',
#  'TEAK_large_033_job_ids.pkl',
#  'TEAK_large_034_job_ids.pkl',
#  'TEAK_large_035_job_ids.pkl',
#  'TEAK_large_036_job_ids.pkl',
#  'TEAK_large_037_job_ids.pkl',
#  'TEAK_large_038_job_ids.pkl',
#  'TEAK_large_039_job_ids.pkl',
#  'TEAK_large_040_job_ids.pkl',
#  'TEAK_large_041_job_ids.pkl',
#  'TEAK_large_042_job_ids.pkl',
#  'TEAK_large_043_job_ids.pkl',
#  'TEAK_large_044_job_ids.pkl',
#  'TEAK_large_045_job_ids.pkl',
#  'TEAK_large_046_job_ids.pkl',
#  'TEAK_large_047_job_ids.pkl',
#  'TEAK_large_048_job_ids.pkl',
#  'TEAK_large_049_job_ids.pkl',
#  'TEAK_large_050_job_ids.pkl',
#  'TEAK_large_051_job_ids.pkl',
#  'TEAK_large_052_job_ids.pkl',
#  'TEAK_large_053_job_ids.pkl',
#  'TEAK_large_054_job_ids.pkl',
#  'TEAK_large_056_job_ids.pkl',
#  'TEAK_large_057_job_ids.pkl',
#  'TEAK_large_058_job_ids.pkl',
#  'TEAK_large_059_job_ids.pkl',
#  'TEAK_large_060_job_ids.pkl',
#  'TEAK_large_061_job_ids.pkl',
#  'TEAK_large_062_job_ids.pkl',
#  'TEAK_large_063_job_ids.pkl',
#  'TEAK_large_064_job_ids.pkl',
#  'TEAK_large_065_job_ids.pkl',
#  'TEAK_large_066_job_ids.pkl',
#  'TEAK_large_067_job_ids.pkl',
#  'TEAK_large_068_job_ids.pkl',
#  'TEAK_large_069_job_ids.pkl',
#  'TEAK_large_070_job_ids.pkl',
#  'TEAK_large_071_job_ids.pkl',
#  'TEAK_large_072_job_ids.pkl',
#  'TEAK_large_073_job_ids.pkl',
#  'TEAK_large_074_job_ids.pkl',
#  'TEAK_large_075_job_ids.pkl',
#  'TEAK_large_076_job_ids.pkl',
#  'TEAK_large_077_job_ids.pkl',
#  'TEAK_large_078_job_ids.pkl',
#  'TEAK_large_079_job_ids.pkl',
#  'TEAK_large_080_job_ids.pkl',
#  'TEAK_large_081_job_ids.pkl',
#  'TEAK_large_082_job_ids.pkl',
#  'TEAK_large_083_job_ids.pkl',
#  'TEAK_large_084_job_ids.pkl',
#  'TEAK_large_085_job_ids.pkl',
#  'TEAK_large_086_job_ids.pkl',
#  'TEAK_large_087_job_ids.pkl',
#  'TEAK_large_088_job_ids.pkl',
#  'TEAK_large_089_job_ids.pkl',
#  'TEAK_large_090_job_ids.pkl',
#  'TEAK_large_091_job_ids.pkl',
#  'TEAK_large_092_job_ids.pkl',
#  'TEAK_large_093_job_ids.pkl',
#  'TEAK_large_094_job_ids.pkl',
#  'TEAK_large_095_job_ids.pkl',
#  'TEAK_large_096_job_ids.pkl',
#  'TEAK_large_098_job_ids.pkl',
#  'TEAK_large_099_job_ids.pkl',
#  'TEAK_large_100_job_ids.pkl',
#  'TEAK_large_101_job_ids.pkl',
#  'TEAK_large_102_job_ids.pkl',
#  'TEAK_large_103_job_ids.pkl',
#  'TEAK_large_104_job_ids.pkl',
#  'TEAK_large_105_job_ids.pkl',
#  'TEAK_large_106_job_ids.pkl',
#  'TEAK_large_107_job_ids.pkl',
#  'TEAK_large_108_job_ids.pkl',
#  'TEAK_large_109_job_ids.pkl',
#  'TEAK_large_110_job_ids.pkl',
#  'TEAK_large_111_job_ids.pkl',
#  'TEAK_large_112_job_ids.pkl',
#  'TEAK_large_113_job_ids.pkl',
#  'TEAK_large_114_job_ids.pkl',
#  'TEAK_large_115_job_ids.pkl',
#  'TEAK_large_116_job_ids.pkl',
#  'TEAK_large_117_job_ids.pkl',
#  'TEAK_large_118_job_ids.pkl',
#  'TEAK_large_119_job_ids.pkl',
#  'TEAK_large_120_job_ids.pkl',
#  'TEAK_large_121_job_ids.pkl',
#  'TEAK_large_122_job_ids.pkl',
#  'TEAK_large_123_job_ids.pkl',
#  'TEAK_large_124_job_ids.pkl',
#  'TEAK_large_125_job_ids.pkl',
#  'TEAK_large_126_job_ids.pkl',
#  'TEAK_large_127_job_ids.pkl',
#  'TEAK_large_128_job_ids.pkl',
#  'TEAK_large_129_job_ids.pkl',
#  'TEAK_large_130_job_ids.pkl',
#  'TEAK_large_131_job_ids.pkl',
#  'TEAK_large_132_job_ids.pkl',
#  'TEAK_large_133_job_ids.pkl',
#  'TEAK_large_134_job_ids.pkl',
#  'TEAK_large_135_job_ids.pkl',
#  'TEAK_large_136_job_ids.pkl',
#  'TEAK_large_137_job_ids.pkl',
#  'TEAK_large_138_job_ids.pkl',
#  'TEAK_large_139_job_ids.pkl',
#  'TEAK_large_140_job_ids.pkl',
#  'TEAK_large_141_job_ids.pkl',
#  'TEAK_large_142_job_ids.pkl',
#  'TEAK_large_143_job_ids.pkl',
#  'TEAK_large_144_job_ids.pkl',
#  'TEAK_large_145_job_ids.pkl',
#  'TEAK_large_146_job_ids.pkl',
#  'TEAK_large_147_job_ids.pkl',
#  'TEAK_large_148_job_ids.pkl',
#  'TEAK_large_149_job_ids.pkl',
#  'TEAK_large_150_job_ids.pkl',
#  'TEAK_large_151_job_ids.pkl',
#  'TEAK_large_152_job_ids.pkl',
#  'TEAK_large_153_job_ids.pkl',
#  'TEAK_large_154_job_ids.pkl',
#  'TEAK_large_155_job_ids.pkl',
#  'TEAK_large_156_job_ids.pkl',
#  'TEAK_large_157_job_ids.pkl',
#  'TEAK_large_158_job_ids.pkl',
#  'TEAK_large_159_job_ids.pkl',
#  'TEAK_large_160_job_ids.pkl',
#  'TEAK_large_161_job_ids.pkl',
#  'TEAK_large_162_job_ids.pkl',
#  'TEAK_large_163_job_ids.pkl',
#  'TEAK_large_164_job_ids.pkl',
#  'TEAK_large_165_job_ids.pkl',
#  'TEAK_large_166_job_ids.pkl',
#  'TEAK_large_167_job_ids.pkl',
#  'TEAK_large_168_job_ids.pkl',
#  'TEAK_large_169_job_ids.pkl',
#  'TEAK_large_170_job_ids.pkl',
#  'TEAK_large_171_job_ids.pkl',
#  'TEAK_large_172_job_ids.pkl',
#  'TEAK_large_173_job_ids.pkl',
#  'TEAK_large_174_job_ids.pkl',
#  'TEAK_large_175_job_ids.pkl',
#  'TEAK_large_176_job_ids.pkl',
#  'TEAK_large_177_job_ids.pkl',
#  'TEAK_large_178_job_ids.pkl',
#  'TEAK_large_179_job_ids.pkl',
#  'TEAK_large_180_job_ids.pkl',
#  'TEAK_large_181_job_ids.pkl',
#  'TEAK_large_182_job_ids.pkl',
#  'TEAK_large_183_job_ids.pkl',
#  'TEAK_large_184_job_ids.pkl',
#  'TEAK_large_185_job_ids.pkl',
#  'TEAK_large_186_job_ids.pkl',
#  'TEAK_large_187_job_ids.pkl',
#  'TEAK_large_188_job_ids.pkl',
#  'TEAK_large_189_job_ids.pkl',
#  'TEAK_large_190_job_ids.pkl',
#  'TEAK_large_191_job_ids.pkl',
#  'TEAK_large_192_job_ids.pkl',
#  'TEAK_large_193_job_ids.pkl',
#  'TEAK_large_194_job_ids.pkl',
#  'TEAK_large_195_job_ids.pkl',
#  'TEAK_large_196_job_ids.pkl',
#  'TEAK_large_197_job_ids.pkl',
#  'TEAK_large_198_job_ids.pkl',
#  'TEAK_large_199_job_ids.pkl',
#  'TEAK_large_200_job_ids.pkl',
#  'TEAK_large_201_job_ids.pkl',
#  'TEAK_large_202_job_ids.pkl',
#  'TEAK_large_203_job_ids.pkl',
#  'TEAK_large_204_job_ids.pkl',
#  'TEAK_large_205_job_ids.pkl',
#  'TEAK_large_206_job_ids.pkl',
#  'TEAK_large_207_job_ids.pkl',
#  'TEAK_large_208_job_ids.pkl',
#  'TEAK_large_209_job_ids.pkl',
#  'TEAK_large_210_job_ids.pkl',
#  'TEAK_large_211_job_ids.pkl',
#  'TEAK_large_212_job_ids.pkl',
#  'TEAK_large_213_job_ids.pkl',
#  'TEAK_large_214_job_ids.pkl',
#  'TEAK_large_215_job_ids.pkl',
#  'TEAK_large_216_job_ids.pkl',
#  'TEAK_large_217_job_ids.pkl',
#  'TEAK_large_218_job_ids.pkl',
#  'TEAK_large_219_job_ids.pkl',
#  'TEAK_large_220_job_ids.pkl',
#  'TEAK_large_221_job_ids.pkl',
#  'TEAK_large_222_job_ids.pkl',
#  'TEAK_large_223_job_ids.pkl',
#  'TEAK_large_224_job_ids.pkl',
#  'TEAK_large_225_job_ids.pkl',
#  'TEAK_large_226_job_ids.pkl',
#  'TEAK_large_227_job_ids.pkl',
#  'TEAK_large_228_job_ids.pkl',
#  'TEAK_large_229_job_ids.pkl',
#  'TEAK_large_230_job_ids.pkl',
#  'TEAK_large_231_job_ids.pkl',
#  'TEAK_large_232_job_ids.pkl',
#  'TEAK_large_233_job_ids.pkl',
#  'TEAK_large_234_job_ids.pkl',
#  'TEAK_large_235_job_ids.pkl',
#  'TEAK_large_237_job_ids.pkl',
#  'TEAK_large_238_job_ids.pkl',
#  'TEAK_large_239_job_ids.pkl',
#  'TEAK_large_240_job_ids.pkl',
#  'TEAK_large_241_job_ids.pkl',
#  'TEAK_large_242_job_ids.pkl',
#  'TEAK_large_243_job_ids.pkl',
#  'TEAK_large_244_job_ids.pkl',
#  'TEAK_large_245_job_ids.pkl',
#  'TEAK_large_246_job_ids.pkl',
#  'TEAK_large_247_job_ids.pkl',
#  'TEAK_large_248_job_ids.pkl',
#  'TEAK_large_249_job_ids.pkl']

# %%
filepath = job_ids_dir + submitted_jobs[20],
with open(filepath, 'rb') as f:
    job_ids = pickle.load(f)

unsuc = get_unsuccessful_jobs_in_list(job_ids)
print(len(unsuc))




failed_job_urls = [job_result_for(job) for job in unsuc]
failed_params = [to_failed_job_params(url) for url in failed_job_urls]
failed_inputs = [get_failed_job_input_LAS(json) for json in failed_params]

failed_inputs

## only want to check all the jobs once. so we will make a list of every single failed job
## and store them as a dict, with the key being the s3 url and the value being the job ID
## then after we make and save the failed jobs dict
## iterate over the dict , make kwargs from the key,
# Out:
# 5
# ['s3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_028/TEAK_large_028_pc_1400.rds',
#  's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_028/TEAK_large_028_pc_1494.rds',
#  's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_028/TEAK_large_028_pc_716.rds',
#  's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_028/TEAK_large_028_pc_97.rds',
#  's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_028/TEAK_large_028_pc_974.rds']

# %%
get_f

# %%
    # Initialize job states
    final_states = ["Succeeded", "Failed", "Deleted"]

    job_states = {job_id: "" for job_id in job_ids}
    update_job_states(job_states, final_states, batch_size=50, delay=10)

    known_completed = len([state for state in job_states.values()
                           if state in final_states])

    while True:
        try:
            with tqdm(total=len(job_ids), desc="Jobs Completed", unit="job") as pbar:
                while any(state not in final_states for state in job_states.values()):

                    # Update the job states
                    n_new_completed: int = update_job_states(job_states,
                                                             final_states,
                                                             batch_size = 50,
                                                             delay = 10)

                    # Update the progress bar
                    pbar.update(n_new_completed)
                    last_updated = datetime.datetime.now()
                    known_completed += n_new_completed
                    
                    status_counts = {status: list(job_states.values()).count(status)
                                     for status in final_states + ["Accepted", "Running"]}
                    status_counts["Other"] = len(job_states) - sum(status_counts.values())
                    status_counts["Last updated"] = last_updated.strftime("%H:%M:%S")

                    pbar.set_postfix(status_counts, refresh=True)

                    if known_completed == len(job_ids):
                        break

                    time.sleep(check_interval)

        except KeyboardInterrupt:
            print("Are you sure you want to cancel the process?")
            print("Press Ctrl+C again to confirm, or wait to continue.")
            try:
                time.sleep(3)
                print("Continuing...")
            except KeyboardInterrupt:
                print("Model run aborted.")
                pending_jobs = [job_id for job_id, state in job_states.items()
                                if state not in final_states]
                click.echo(f"Cancelling {len(pending_jobs)} pending jobs.")
                for job_id in pending_jobs:
                    maap.cancelJob(job_id)
                break
        else:
            break

    # Process the results once all jobs are completed
    succeeded_job_ids = get_succeeded_jobs_in_list(job_ids)
    
    failed_job_ids = get_failed_jobs_in_list(job_ids)

    other_job_ids = get_other_status_jobs_in_list(job_ids) 

    click.echo(f"Processing results for {len(succeeded_job_ids)} "
               f"succeeded jobs.")

    click.echo(f"Gathering tarball paths from succeeded jobs.")

    tar_paths = []
    for job_id in tqdm(succeeded_job_ids):
        job_result_url = job_result_for(job_id)
        time.sleep(1) # to avoid overwhelming the API
        job_output_dir = to_job_output_dir(job_result_url, username)
        # Find .tar.gz file in the output dir
        tar_file = [f for f in os.listdir(job_output_dir)
                     if f.endswith('.tar.gz')]
        if len(tar_file) > 1:
            warnings.warn(f"Multiple .tar.gz files found in "
                          f"{job_output_dir}.")
        if len(tar_file) == 0:
            warnings.warn(f"No .tar.gz files found in "
                          f"{job_output_dir}.")
        if tar_file:
            tar_paths.append(os.path.join(job_output_dir, tar_file[0]))

    # Log the succeeded and failed job IDs
    logging.info(f"{len(succeeded_job_ids)} jobs succeeded.")
    logging.info(f"Succeeded job IDs: {succeeded_job_ids}\n")
    logging.info(f"{len(failed_job_ids)} jobs failed.")
    logging.info(f"Failed job IDs: {failed_job_ids}\n")
    logging.info(f"{len(other_job_ids)} jobs in other states.")
    logging.info(f"Other job IDs: {other_job_ids}\n")

    # Copy all tarballs to the output directory
    click.echo(f"Copying {len(tar_paths)} Tarballs to {output_dir}.")
    copy_batch_count = 0
    for tar_path in tqdm(tar_paths):
        try:
            shutil.copy(tar_path, output_dir)
            copy_batch_count += 1
            if copy_batch_count == 50:
                time.sleep(60)
                copy_batch_count = 0
            else:
                time.sleep(2)
            
        except Exception as e:
            warnings.warn(f"Error copying {tar_path} to {output_dir}: {str(e)}")
            click.echo("Retrying in 10 seconds.")
            time.sleep(10)
            try:
                shutil.copy(tar_path, output_dir)
            except Exception as e:
                click.echo(f"Retry failed: {str(e)}")
                click.echo(f"Skipping {tar_path}.")
                continue

    # Compress the output directory
    # click.echo(f"Compressing output directory.")
    # shutil.make_archive(output_dir, 'zip', output_dir)
    # click.echo(f"Output directory compressed to {output_dir}.zip.")

    end_time = datetime.datetime.now()

    log_and_print(f"Model run completed at {end_time}.")
    
# if __name__ == "__main__":
#     main()

# %%
with open(kwargs_file, 'rb') as f:
    kwargs = pickle.load(f)
# Out:
# [{'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_10.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_100.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1000.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1001.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1002.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1003.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1004.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1005.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1006.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1007.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1008.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1009.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_101.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1010.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1011.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1012.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1013.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1014.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1015.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1016.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1017.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1018.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1019.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_102.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1020.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1021.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1022.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1023.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1024.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1025.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1026.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1027.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1028.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1029.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_103.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1030.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1031.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1032.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1033.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1034.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1035.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1036.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1037.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1038.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1039.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_104.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1040.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1041.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1042.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1043.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1044.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1045.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1046.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1047.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1048.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1049.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_105.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1050.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1051.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1052.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1053.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1054.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1055.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1056.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1057.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1058.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1059.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_106.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1060.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1061.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1062.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1063.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1064.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1065.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1066.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1067.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1068.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1069.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_107.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1070.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1071.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1072.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1073.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1074.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1075.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1076.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1077.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1078.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1079.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_108.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1080.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1081.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1082.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1083.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1084.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1085.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1086.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1087.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1088.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1089.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_109.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1090.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1091.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1092.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1093.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1094.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1095.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1096.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1097.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1098.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1099.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_11.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_110.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1100.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1101.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1102.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1103.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1104.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1105.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1106.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1107.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1108.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1109.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_111.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1110.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1111.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1112.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1113.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1114.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1115.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1116.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1117.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1118.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1119.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_112.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1120.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1121.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1122.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1123.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1124.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1125.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1126.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1127.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1128.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_1129.rds',
# ...
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_414.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_415.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_416.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_417.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_418.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_419.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_42.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_420.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_421.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_422.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_423.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_424.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_425.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_426.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_427.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_428.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_429.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_43.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_430.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_431.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_432.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_433.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_434.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_435.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_436.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_437.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_438.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_439.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_44.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_440.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_441.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_442.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_443.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_444.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_445.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_446.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_447.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_448.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_449.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_45.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_450.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_451.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_452.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_453.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_454.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_455.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_456.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_457.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  {'identifier': 'Mean Shift Segment LAS',
#   'algo_id': 'MS-Step-2-Segment-v2',
#   'version': 'main',
#   'username': 'jclayton0',
#   'queue': 'maap-dps-cuny-worker-64gb',
#   'Point Cloud RDS': 's3://maap-ops-workspace/jclayton0/run_output_20241115_131005/TEAK_large_027/TEAK_large_027_pc_458.rds',
#   'Subplot_widthFrac_cores': 0.9},
#  ...]

# %% [markdown]
# ## What is gone:
#
# * Code to make the kwargs from the directory
# * Code to save the kwargs as pickles
# * Code to read the kwargs from pickles and submit the jobs
# * Any other code and notes I had there.

# %% [markdown]
# ## What to do:
#
# 1. Restart the shell script
# 2. Make internal hyperlinks
# 3. Plan every part of the rest of this
# 4. rewrite missing code
# 5. Push to github regularly
# 6. Change step 1 so that it does not tarball things.

# %% [markdown]
# # What does the script still need to do?
#
# 1. Missing old parts up to submitting the segmentation jobs
# 2. Check every job ID for missing, resubmit the failed, and then overwrite the failed IDs
#    * probably this looks like copying the successful IDs over and adding the newly submitted IDs to that list, then saving that list in the same file
# 3. Move all the segmented tiles into one directory and tarball them
#    * this looks like what I did before: gather the paths for each and save them to a pkl, then move them en masse to new dir.
#    * Then this looks like: tarballing them all
# 4. Then write a script to gather all the tarball paths and make kwargs from them
# 5. Then submit these all as jobs to step 3
# 6. Then gather outputs and move them, again.
# 7. Finally submit everything that's left to step 4.
# 8. Gather Step 4 outputs and then make the CSV. Probably on our server.
